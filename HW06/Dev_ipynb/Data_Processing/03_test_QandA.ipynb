# %%
import PyPDF2
import glob
import numpy as np
import pdfplumber
from collections import defaultdict
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure

# %%
def text_extraction(element):
    
    line_text = element.get_text()
    
    line_formats = []
    for text_line in element:
        
        if isinstance(text_line, LTTextContainer):
            
            for character in text_line:
                
                if isinstance(character, LTChar):
                    
                    line_formats.append(character.fontname)
                    
                    line_formats.append(character.size)
                    
    format_per_line = list(set(line_formats))
    
    return (line_text, format_per_line)

def analyst_executives(path):
    
    time=0
    presentation_index=0
    Elon_Musk_index=0
    Question_and_Answer_index=0
    Elon_Musk_speech=[]
    presentation_speech=[]
    text=[]
    executives_name=[]
    analysts_name=[]

    executives_title=[]
    analysts_title=[]

    executives_index=0
    analysts_index=0

    for pagenum, page in enumerate(extract_pages(path)):
        
        for _, element in enumerate(page):

            if pagenum == 2:

                if isinstance(element, LTTextContainer):
                    line_text, format_per_line = text_extraction(element)

                text.append(line_text)

                if line_text == "EXECUTIVES\n":
                    executives_index+=1

                if line_text == 'ANALYSTS\n':
                    executives_index=0

                if executives_index >= 1:
                    executives_name.append(line_text.split("\n")[0])
                    executives_title.append(line_text.split("\n")[1])

                if line_text == 'ANALYSTS\n':
                    analysts_index+=1
                    executives_index=0

                if 'S&P Global Market Intelligence' in line_text:
                    analysts_index=0

                if analysts_index >= 1:
                    analysts_name.append(line_text.split("\n")[0])    
                    analysts_title.append(line_text.split("\n")[1])

        if pagenum == 4:
            break

    ppl=defaultdict(lambda: defaultdict(str))

    for i in range(1, len(analysts_name), 1):

        ppl['analysts'][analysts_name[i]]=analysts_title[i]

    for i in range(1, len(executives_name), 1):

        ppl['executives'][executives_name[i]]=executives_title[i]
    
    return ppl

# %%
files=glob.glob("/Volumes/4TB/ConferenceCall/Tesla/Earningcall/*.pdf")
path=files[0]
print(path)
pdf=open(path, 'rb')
pdfReader=PyPDF2.PdfReader(pdf)

ppl=analyst_executives(path)

ppl['executives'].items()
executives_people=[elem[0] for elem in ppl['executives'].items()]
executives_title=[elem[1] for elem in ppl['executives'].items()]

ppl['analysts'].items()
analysts_people=[elem[0] for elem in ppl['analysts'].items()]
analysts_title=[elem[1] for elem in ppl['analysts'].items()]
# Out:
# /Volumes/4TB/ConferenceCall/Tesla/Earningcall/Tesla Motors, Inc., Q1 2011 Earnings Call, May 04, 2011.pdf

# %%
executives_people
# Out:
# ['Deepak Ahuja', 'Elon R. Musk', 'Jeffrey K. Evanson']

# %%
def processing_qa(path):
    
    presentation_index=0
    Elon_Musk_index=0
    Question_and_Answer_index=0
    Elon_Musk_speech=[]
    question_and_answer_speech=[]
    time=0

    for pagenum, page in enumerate(extract_pages(path)):
        
        print('page={}'.format(pagenum, page))
        
        for _, element in enumerate(page):
            
            if isinstance(element, LTTextContainer):

                line_text, format_per_line = text_extraction(element)
            
            if pagenum == 0:
                
                if _ == 0:
                    
                    time=line_text
                    time=time[61:100]
            
            if ("S&P Global Market Intelligence" in line_text)|("TESLA, INC."  in line_text):
        
                pass
        
            else:

                if line_text == 'Presentation\n':

                    presentation_index = presentation_index + 1

                if line_text == 'Question and Answer\n':

                    Question_and_Answer_index = Question_and_Answer_index + 1

                if Question_and_Answer_index == 2:

                    question_and_answer_speech.append(line_text)

                if pagenum == pdfReader.pages.length_function()-1:

                    break
                
    return question_and_answer_speech

# %%
question_and_answer_speech=processing_qa(path)
# Out:
# page=0
# page=1
# page=2
# page=3
# page=4
# page=5
# page=6
# page=7
# page=8
# page=9
# page=10
# page=11
# page=12
# page=13
# page=14
# page=15
# page=16
# page=17
# page=18

# %%
question_and_answer_speech
# Out:
# ['Question and Answer\n',
#  'Operator\n',
#  '[Operator Instructions] Our first question is from Patrick Archambault of Goldman Sachs.\n',
#  'Patrick Kenehan Archambault\nGoldman Sachs Group Inc., Research Division\n',
#  "So I guess a couple questions, maybe first on just the marketing side. You've opened up Santana Row\nand I believe there was some talk about also broadening up the approach to have maybe smaller selling\npoints in public places like malls and stuff like that. Can you tell us a little bit about like how your retailing\nstrategy has evolved now that you are obviously ramping it up more aggressively? That would be my first\nquestion.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Sure, our goal with Tesla though has been to try to reinvent the sales and service process, because I\nthink it's pretty bad in the conventional industry. In fact, most people would rate purchasing a car as their\nworst retail experience, some regard it as one of those [indiscernible]. So we really want to be the polar\nopposite of that. We want it to be, buying a car is something you look forward to, that it's a delightful\nexperience. We want to have stores that you're drawn to come in even if you don't really need to buy a car\nat the time. And so, we'll try -- we're reiterating, since opening up our first store a few years ago, trying\nto refine this and Santana Row is basically the latest version of the store, if you will, store version 3 or\nsomething like that. And then, I think we're really getting it pretty dialed in. We're seeing tremendous\ntrack record at the stores, thousands of people coming in per week. And while this is slightly helpful\nfor Roadster, it's really helpful for Model S and for future vehicles that we will bring out that are more\naffordable. I'd really recommend going and visiting the Santana Row store to get a visual sense of what\nI'm talking about, because it's hard to describe exactly, but easy to understand if you go there.\n",
#  'Patrick Kenehan Archambault\nGoldman Sachs Group Inc., Research Division\n',
#  "And I guess, just building on that, is your -- I believe the original plan was to not really do much\ntraditional marketing at all. I guess, because it was the volume you're targeting, probably it might not\nhave been necessary. Is that still the view? Or is that something that you might engage in to increase\nawareness on the Model S --\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Well, I mean clearly, since we're almost -- not far from having sold out of all of next year's production of\nModel S, and it's not yet next year. There's clearly no need for advertising yet. At some point, there may\nbe a need for advertising, but that's only going to be when we're not production constrained. So we're\nalso going to focus our energies on ensuring that we're not production constrained. And that's why we\nreconfigured the plan to make the Model S production, the 20,000 units production, on 1 shift instead of 2\nshifts, so that we have the ability to potentially to double the production, fairly quickly, if need be. But we\nreally don't anticipate any short- to medium-term need for advertising expenditures of any kind, really.\n",
#  'Patrick Kenehan Archambault\nGoldman Sachs Group Inc., Research Division\n',
#  "Okay. And just a couple of more housekeeping questions. I mean, Deepak, do you have -- can you give us\nthe working capital number? I know that you'll give it in the queue later, but do you have that handy? And\nthe other thing I was looking for is can you give us the split in terms of the U.S. versus international sales\nthat you saw for the Roadster?\n",
#  '8\n',
#  '8\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "Let me answer the second question first. This was in fact our first quarter where we saw our international\nsales to be slightly more than U.S. sales in our history. So it's a good indication of the growth and\npresence of Tesla outside of the U.S., in Europe and in Asia. We already really saw some good growth in\nJapan and the Asian markets in Q1. And regarding the working capital discussion, I think our cash flow\nstatement and our usage of operating cash is the answer. I'm not exactly sure what further information\nyou're looking for, Pat.\n",
#  'Patrick Kenehan Archambault\nGoldman Sachs Group Inc., Research Division\n',
#  "I'm sorry, I'm just looking at it now. We can follow up online. I just saw a use in operating activity, so I\nwas just wondering what portion of that was -- in the $43 million, was a working capital use versus other\noperating uses of cash.\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  'I think, as I mentioned in the call, the working capital usage would be from inventory as well as accounts\nreceivable. And those are the primary drivers for the slight increase in our working capital this quarter\ncompared to the previous one.\n',
#  'Patrick Kenehan Archambault\nGoldman Sachs Group Inc., Research Division\n',
#  'Okay. So just the Delta and those 2 items will get us the number? Okay.\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Actually, one thing I've got to mention regarding Model S is our sales team is not selling Model S. They're\nselling Roadster. So the sales growth you've seen from Model S is not due to say S ramping up the sales\nof Model S. In fact, there isn't even a Model S in the Santana Row store, I think that may not be obvious\nbased on my last comments.\n",
#  'Operator\n',
#  'Our next question is from Dan Galves of Deutsche Bank.\n',
#  'Daniel V. Galves\nDeutsche Bank AG, Research Division\n',
#  'I just wanted to ask -- interesting that the international sales were higher in the quarter than the U.S. I\njust wanted to ask about option content uptake from consumers. It seems like it stayed pretty steady with\nthe Roadster, given steady average transaction prices. Are you seeing any differences in the amount of\noptions people buy internationally versus U.S.? And does that provide any lessons for Model S for you?\nAnd then also, just a follow-up is, are you planning on offering a leasing program for the Model S? And is\nthere any update on the financing for that leasing program?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think our options mix is pretty comparable between regions. If there is any significant statistical\ndifference, they're pretty minor. And in terms...\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  '9\n',
#  '9\n',
#  "Yes. Regarding providing a leasing option on the Model S, definitely, that is in our plan, and we've been\nworking with a bank to partner with us regarding that. And we'll announce the details when they are in\nplace. But we'll definitely offer leasing as a financing option for our customers.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Yes. We're actually seeing quite strong interest from some of the major banks in working with us on a\nleasing program for the Model S with quite compelling numbers. It looks like there may be a bit of a\nbetting war there, which is good.\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "And we're also working with banks regionally in the sense, obviously, we'll have a partner in Europe\ndifferent from the U.S. So we will have regional concentrations there too.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Yes. And Europe has -- I've seen us adapt to the different environments, and Europe has a very strong\ncorporate leasing program. A lot of their cars are actually company cars, effectively. So we're making sure\nthat the Model S is well-positioned to be in the company car programs.\n",
#  'Daniel V. Galves\nDeutsche Bank AG, Research Division\n',
#  'Okay, excellent. Just one other one. I just wanted to ask about performance in terms of quality, quality\nperformance of the drivetrain on the Roadster. How have warranty trends been going as some of the\nvehicles probably get a little older? Just asking about that? Has it been, to your expectations, better or\nworse?\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "Yes, Dan. We haven't seen any significant change in the trend of our warranty work on these cars. So\nthere has been no significant change in our warranty reserves. As a result, this quarter, it's been pretty\nsteady state.\n",
#  'Daniel V. Galves\nDeutsche Bank AG, Research Division\n',
#  'Great, and do you want to follow-up, Elon?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "None of our customers have actually -- no battery pack has yet reached end of light and it's been, now,\nabout 3 years. So even ones that have been driven very heavily, that are approaching 100,000 miles.\n",
#  'Operator\n',
#  'Our next question is from Adam Jonas of Morgan Stanley.\n',
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  "I just want to drill in a bit more on the Model S. First, the reservations. Of the 1,200 additional\nreservations you've had since the start of the year, any detail on, geographically, how those are spread?\nAnd also, how much has that acceleration in the reservations been influenced by the growth in the\nfootprint, in particular, the Santana Row, and knowing, of course, you don't have a vehicle in the\nshowroom. But just how much of that spur reservation activity as well?\n",
#  '10\n',
#  '10\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Well, it's difficult to say how it's spread, it's got to have some help but it's -- is how much? I think the\nbiggest thing affecting Model S reservation factor is that we're sort of getting close to deliveries and\nthere's a lot more detail being released about the car. And we were trying to be as open as possible to the\ncustomers about the progress we make. We have journalists days, to come in and take a look at the alpha\ncars. And that's been very well received. So I think it's more press than anything else that's the bigger\ndriver. But certainly, the stores are part of it. As I said, the sales people at stores are actually instructed to\nfocus on Roadster, not on Model S because we don't yet have the Model S vehicles in the stores to really\nactively sell. Model S reservations right now are, I don't have the exact numbers with me, but buyers are\npretty strongly towards North America. Yes, at least, sort of in the order of 3/4, North America. But part of\nthat is because we'll deliver in North America first. So we deliver in North America in middle of next year,\nEurope end of next year. And then our right-hand drive vehicle, which is key for U.K., is only in 2013. So\nI think we'll start, we'll see the mix of sales for Model S start to get roughly comparable between North\nAmerica and Europe down the road. But that's probably happens like next year or something like that.\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "Also, we haven't really kicked off accepting reservations for Model S.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'Right. [indiscernible] . We have to do reservation in dollars.\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "Right. So as we get systematically -- while we put in the processes to collect reservations systematically\nin Asia and most of Europe, we'll see a much bigger uptick there. There is potential that we haven't really\nexploited.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "We don't even have a local language site. So, if you got to read it in English, you'll pay in dollars. We also\nneed to correct those issues.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  'And just a follow-up, and you mentioned, you have some journalist day scheduled. But specifically, when\ncan we drive it? When can we expect the journalist to begin driving either the late alpha prototype or beta\nversion realistically? And then when could you have us out there driving it ourselves?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think, particularly, given that it's a car and safety is paramount, I think testing at the beta level is about\nthe first time that we'd let non-Tesla personnel drive the car. And we're expecting to have the first betas\ndone at the end of the summer. So that's about when you can expect non-Tesla people to be able to drive\nthe car. Yes.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  "Okay, that's clear. A question on CapEx. You're obviously running far below the run rate. You're going to\nhave to catch up to come anywhere near the $190 million to $215 million, but any way you could explain\nto us, of the remaining 3 quarters this year, how lumpy that CapEx will be? I mean will it be smooth\n",
#  '11\n',
#  '11\n',
#  'roughly $60 million per quarter? Is it the heavily, heavily weighted towards the end of the year? Any rough\ncurve of that CapEx spend would be appreciated.\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "I think it will be fairly, fairly small delivered [ph] 3 quarters. CapEx statements, as you can imagine, tend\nto be large and lumpy. So even a 1 week or 2 delay in payment can significantly move the recognition of\nCapEx from 1 quarter to the other. So I wouldn't be very far more clear in my guidance on that issue, but\nwe have very clear visibility of what our CapEx spending will be over the next few quarters, and yes...\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "[indiscernible] CapEx expenditures, but not to the granularity of the quarter. Because like a few payments\ndelayed, 1 month to next, can make a pretty big difference. But I mean, there's apart from a few minor\nones, all of our supplier deals are done. I mean the Model S is almost 100% sold at this point. So we --\nunless suppliers break their deals or something, then it's in the premium [ph] quantities.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  "But the point is, is that the lower spending level isn't so much that you're getting more bang for the buck.\nIt's just that lumpiness and the timing issue and you...\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'Yes.\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  'Exactly.\n',
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  "Okay, that's clear.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think we're getting pretty good bang for the buck to begin with.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  'Right, the bar is raised for you.\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "That's true. Yes. And based with the capital we have on hand and the DoE loan, we do have enough capital\nbased on our projections to reach cash flow positive and possible to without ever-raising another dollar.\nBut as we said in the last quarter, there's a decent chance for lower rates secondary for the Model X\nactivity, some additional potential headwind growth on the Model S production. And then, just -- it's a\ngood idea to have a larger road [ph] but smaller cash cushion.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  '12\n',
#  '12\n',
#  'Since you brought that up, one final question then. I mean, you mentioned the word secondary. Would\nyou preferred -- I mean, obviously, leaving room to be opportunistic and whatever method of capital raise\nyou would do, is the preference more towards equity rather than debt or convert?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think we're probably on earning side of equity. Since we have a favored effect with the DoE loan.\n",
#  'Adam Michael Jonas\nMorgan Stanley, Research Division\n',
#  "You'll probably not going to get better rate than that?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "It's pretty nice.\n",
#  'Operator\n',
#  'Our next question is from Himanshu Patel with JP Morgan.\n',
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "A couple of questions, just on the issue of additional fund-raising. Elon, maybe, or Deepak, can you talk a\nlittle bit about, just aside from market conditions, what are the kind of key governing factors that is going\nto help you guys decide how much to raise and when to raise? Is this really just about primarily the Model\nX and how fast you'd like to follow up with another car after the Model S? Or are there other things here\nthat we're not thinking about? And I want to supplement that question, could additional fund-raising needs\nalso be satisfied with may be having another strategic investor come into the company as opposed to a\npublic market transaction?\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "I think, Himanshu, I'd like to just sort of step back and not answer this question to this level of detail. I\nthink, as you can imagine, like any other company, we will evaluate our fund-raising needs from time to\ntime, and raise funds opportunistically when it makes sense and when the market conditions are right. So\nI think, it's probably best to leave it at that regarding this question.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'Yes. Obviously, in compliance with financial regulations, we have to be circumspect in discussing future\nfinancing.\n',
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "Okay. The other big question I have is just since you've done your IPO, the euro is up 20%, 25%, and\nI'm just wondering what are kind of the implications of that operationally? You mentioned how the\nEuropean deliveries for the Model S are kind of end of '12 or go '13. Does it make sense to potentially\naccelerate some of that and maybe deemphasize U.S. deliveries initially? And I guess, in addition to\nthat, at a minimum, should we think about the currency rate changes as -- at least being just a direct\nmargin addition to the company on the non-U.S. sales? Or would you consider recalibrating your pricing\nexpectations on European volumes as a result as well?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  '13\n',
#  '13\n',
#  "The reason for starting with the U.S. deliveries is, if we have to deal with any corrective actions on the\ncars, it's a lot easier to get our hands around it if it's in a more tightly contained geographic area and\ncloser to our headquarters. So I think it's important for those first few months to be able to monitor very\nclosely the status of the cars and make sure customers have a wonderful experience and in a worst-\ncase scenario, where there is potentially a recourse or something like that, we can do that quickly and\ntake care of it with minimal disruption. And then, it's also important to note that a car which meets U.S.\nregulations doesn't meet European regulations. So it's not like it's the car in both cases. Unfortunately,\nthey are slightly different. And so, we have to decide which car do we bold first. It's not the same car to\neither market. I think it's possible we could make a little more money if we ship to Europe, maybe even\nprobable if we ship to Europe initially. But I think, the right decision in terms of long-term thinking is to\ndeliver cars initially in the U.S., make sure they're super good, and then expand internationally.\n",
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "And I guess the second question I had is, I think you guys have originally talked about U.S. versus non-\nU.S. volumes for the Model S eventually being kind of even. Just given what's happened...\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I said, North America and Europe would be about even. I think Asia would be at least as big as those. I\nwould say it's something like 1/3 Asia, 1/3 North America, 1/3 Europe.\n",
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "Right. Okay. So I mean just given what the dollar's done, obviously, that's financially very beneficial for\nyour percent margin because you're the only U.S. carmaker exporting from the U.S. really. So I guess\nthe question, Elon, is do you kind of just keep your pricing for that vehicle where you expected it and let\nit all drop down to margin? Or is there a thought here that you could actually grab a lot more volume in\nthe non-U.S. markets to know what currency rates have done by lowering the price points that you were\npreviously thinking about?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think it's a bit dodgy to try to guess currency, and because what's true today can be different a year\nfrom now. And so I think -- we just want to perceive by way of making sure we have the best product at\nthe best price and with incredible value for money in each market. And if some customers are getting a\nbetter deal because of their currencies, should develop [indiscernible] and then get to them.\n",
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  'Has Toyota made any decisions on the final assembly site for the RAV4?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I don't want to speak on Toyota's behalf. So I would ask you to direct that question to Toyota. But\ncertainly, the powertrain is made by Tesla in California.\n",
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "Previously, you've sort of indicated that Tesla is, I guess, agnostic, is maybe the best adjective as to\nwhether or not Toyota wants to do final assembly on Fremont or not. I mean is that still pretty much your\nview?\n",
#  'Elon R. Musk\n',
#  '14\n',
#  '14\n',
#  'Co-Founder, CEO, Director & Product Architect\n',
#  "Toyota is an important customer. We're a supplier to Toyota. So we want to do whatever makes Toyota\nhappy in this regard. And where the powertrain is installed is entirely up to them.\n",
#  'Himanshu A. Patel\nJP Morgan Chase & Co, Research Division\n',
#  "Okay. Can you update us lastly on, I know it's fairly early stages, but on the Model X, you've been talking\na little bit more about it publicly, and I think privately. Have you put any more granularity behind your\nthoughts on timing, any design elements that have kind of been a little bit more solidified in your mind,\nprice points, or is it still all at a fairly conceptual level?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "We're actually hard at work on the Model X in the design studio. But I don't want to let the cat out of the\nbag on what it's going to be like. I mean I think it's shaping up to be something pretty incredible. But I\nthink, we'll let the public be the judge when they see it at the end of this -- we are planning to unveil it at\nthe end of the year, as I said previously. And it will use the same basic -- same powertrain as the Model S.\nThe Model X is built from the Model S platform. So it allows us to leverage that platform with a relatively\nsmall amount of incremental CapEx. And it just addresses a market that is SUV and minivan. So with the\nModel S, we try to make a sedan that is so functional, has so much cargo capacity, can seat 7 people,\nsuch that it addresses those of the sedan market, but also addresses about half of the people that would\notherwise buy an SUV. With the Model X, we're trying to address the other half of people who would buy\nSUV, as well as the people who would buy a minivan. So I'm pretty excited about it, and I think it's going\nto be well received. But we'll see at the end of this year.\n",
#  'Operator\n',
#  'Our next question is from Andrea James of Dougherty.\n',
#  'Andrea Susan James\nDougherty & Company LLC, Research Division\n',
#  "Taking back on the Model X question, do you think there'll be, I guess, some synergies from developing\nthe RAV4? Do you take any of that and move that over and capture that for the Model X development?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "There's a little bit. I wouldn't say it's lot, but there's certainly a little bit of that, that it's in there. And\nof course, working with Toyota, and meeting their extremely stringent standards, as with Daimler, is a\nlearning experience for us. So I think it's definitely helpful, with a lot of mutual learning taking place\nwith us and Toyota. And so, it's definitely a helpful relationship that has intangible benefits beyond the\n[indiscernible] being the partnering style for the RAV4.\n",
#  'Andrea Susan James\nDougherty & Company LLC, Research Division\n',
#  "And as far as R&D long-term and headcount, can you talk a little bit about how you're going to manage\nheadcount going into FY '12, what your expectations are, and then into FY '13?\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "I think that is something we haven't shared much in terms of guidance, Andrea. Obviously, at a higher\nlevel, our focus this year is to continue to grow our manufacturing team and then bring in the workforce to\nmanufacture the car, and a lot of engineering people are already in place since we've spend the time and\nthe effort to develop the Model S. So I'll just leave it at that.\n",
#  '15\n',
#  '15\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Yes. That's sort of the significant double-digit growth in play counts. But yes, it's a little bleak, but\nit's exactly what that number is going to be. Our hiring standard at Tesla are extremely high in that\nunequivocally the highest in the car business. And so that tends to be the getting factor on our hiring\ndecisions more than anything else.\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "The other area that we will see some hiring towards the end of this year and next year is marketing and\nsales as we've put in the infrastructure to sell 20,000 units of Model S globally.\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'Right, absolutely.\n',
#  'Andrea Susan James\nDougherty & Company LLC, Research Division\n',
#  'You had a great gross margin this quarter. Can you talk about the sustainability of that? And once the\nModel S is launched, I guess maybe some of your R&D, does that move up into cost of goods sold?\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  'Yes. Our gross margin on the Automotive side of the business is fairly steady. The gross margin on the\ndevelopment services side is unpredictable because of timing differences and the recognition of revenue\nand cost. So you would definitely see some variation in our gross margin overall, depending on the size\nand the accounting issues around development services. Does that answer your question?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'The Model S, we are expecting higher gross margins with Model S than the Roadster because we are in\nsourcing much more of the Model S.\n',
#  'Andrea Susan James\nDougherty & Company LLC, Research Division\n',
#  "One final one. What's your confidence level with your part sourcing and your suppliers and the delivery?\nI know it's -- just where you are right now, obviously, you're confident you're going to get there. But just\nhow do you feel about it now? And then also, with the manufacturing equipment, are there any delays,\nanything coming from Japan? Yes, so confidence level on suppliers and on manufacturing equipment?\n",
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "Just to elaborate on the last one, we're pretty confident of the 25% gross margin number for Model\nS. That's the number that we expect to be measured by and that we're confident we'll hit. As far as\nsupplier disruptions, we haven't really seen any significant supplier disruptions. So things are proceeding\npretty smoothly. There are a few hiccups here and there for a week or so, but it was less than our buffer\ninventories so it didn't, it really didn't to make a difference.\n",
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "And it hasn't affected on both the Roadster and Model S.\n",
#  'Operator\n',
#  '16\n',
#  '16\n',
#  '[Operator Instructions] Our next question is from Brian [ph] Russell of Russell Group.\n',
#  'Unknown Analyst\n',
#  'Could you talk a little bit about the Daimler situation? You had an additional 300 Smart battery packs\nordered. But I saw somewhere where they decided to go with Bosch on the motors?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "I think you'll note it's sort of an article that didn't actually mean anything. Because we don't supply the\nmotors to Daimler. So in the case of Toyota, we do. For the RAV4, we provide the whole powertrain motor,\ninverter, charger, transmission, and it all connects to everything. So we do it with the whole powertrain\nin the case of RAV4. In case of the Smart and the, let's say, it's A-Class, we provide the battery pack and\ncharger and that's always how it's been.\n",
#  'Unknown Analyst\n',
#  'They said they were going to use Evonik for their battery packs on the production Smart. Is that correct or\nhave you heard anything on that?\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  "That also has been their plan for or their stated plan for quite a long time. However, they also -- what has\nhappened, at least historically, is that Evonik has not been able to provide a product that's as compelling\nas Tesla's, and so then Daimler has, at a very early stage of the process, driven to continue with Tesla.\nThat may change in the future of course, but that's the history stated.\n",
#  'Unknown Analyst\n',
#  'And would I be right in assuming you kind of upped the revenue projection by about $10 million. About\nhalf of is the additional 300 Smart battery charger?\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  "That's correct.\n",
#  'Unknown Analyst\n',
#  'And then where do you see the rest of it? Is it going to be in development services or...\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  'We just have better visibility on all aspects of our business. And it could be from either or. We just feel\nmore comfortable at this point, given that we are in May here with that $10 million increase in revenue\nguidance.\n',
#  'Operator\n',
#  "Thank you. I'm showing no further questions at this time. I'd like to turn the call over to management for\nany closing remarks.\n",
#  'Jeffrey K. Evanson\nFormer Vice President of Investor Relations\n',
#  "Okay. Thank you, Tyrone. We again appreciate all of you taking your time to join us today, and we look\nforward to see many of you during our travels. We're here in Palo Alto or at our first annual shareholder\nmeeting on Wednesday, June 1 from 9 to 10 a.m. The meeting will be held at the Network Meeting Center\nat TechMart in Santa Clara, California. Thank you, everyone, and have a great day.\n",
#  '17\n',
#  '17\n',
#  'Elon R. Musk\nCo-Founder, CEO, Director & Product Architect\n',
#  'Thanks.\n',
#  'Deepak Ahuja\nFormer Chief Financial Officer\n',
#  'Thank you.\n',
#  "Operator\nLadies and gentlemen, thank you for participation in today's conference. This concludes the program. You\nmay now disconnect, and have a wonderful day.\n",
#  '18\n',
#  '18\n',
#  '19\n']

# %%
speech_analysts_people=defaultdict(lambda: defaultdict(str))
speech_executives_people=defaultdict(lambda: defaultdict(str))
speech_analysts_index_dict=defaultdict(lambda: defaultdict(str))
speech_executives_index_dict=defaultdict(lambda: defaultdict(str))
speech_question_index=0
speech_answer_index=0

for _, text in enumerate(question_and_answer_speech):
    
    text=text.split("\n")
    
    print(text)
    
    if "S&P Global Market Intelligence" in text[0]:
        
        pass
        
    else:
        
        for analysts in analysts_people:

            if analysts in text[0]:

                print(analysts)

                speech_analysts_people[str("question_")+str(speech_question_index)]=analysts
                speech_analysts_index_dict[str("question_")+str(speech_question_index)]=_+1
                speech_question_index+=1

        for executives in executives_people:

            if executives in text[0]:

                print(executives)

                speech_executives_people[str("answer_")+str(speech_answer_index)]=executives
                speech_executives_index_dict[str("answer_")+str(speech_answer_index)]=_+1
                speech_answer_index+=1
# Out:
# ['Question and Answer', '']
# ['Operator', '']
# ['[Operator Instructions] Our first question is from Patrick Archambault of Goldman Sachs.', '']
# ['Patrick Kenehan Archambault', 'Goldman Sachs Group Inc., Research Division', '']
# Patrick Kenehan Archambault
# ["So I guess a couple questions, maybe first on just the marketing side. You've opened up Santana Row", 'and I believe there was some talk about also broadening up the approach to have maybe smaller selling', 'points in public places like malls and stuff like that. Can you tell us a little bit about like how your retailing', 'strategy has evolved now that you are obviously ramping it up more aggressively? That would be my first', 'question.', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Sure, our goal with Tesla though has been to try to reinvent the sales and service process, because I', "think it's pretty bad in the conventional industry. In fact, most people would rate purchasing a car as their", 'worst retail experience, some regard it as one of those [indiscernible]. So we really want to be the polar', "opposite of that. We want it to be, buying a car is something you look forward to, that it's a delightful", "experience. We want to have stores that you're drawn to come in even if you don't really need to buy a car", "at the time. And so, we'll try -- we're reiterating, since opening up our first store a few years ago, trying", 'to refine this and Santana Row is basically the latest version of the store, if you will, store version 3 or', "something like that. And then, I think we're really getting it pretty dialed in. We're seeing tremendous", 'track record at the stores, thousands of people coming in per week. And while this is slightly helpful', "for Roadster, it's really helpful for Model S and for future vehicles that we will bring out that are more", "affordable. I'd really recommend going and visiting the Santana Row store to get a visual sense of what", "I'm talking about, because it's hard to describe exactly, but easy to understand if you go there.", '']
# ['Patrick Kenehan Archambault', 'Goldman Sachs Group Inc., Research Division', '']
# Patrick Kenehan Archambault
# ['And I guess, just building on that, is your -- I believe the original plan was to not really do much', "traditional marketing at all. I guess, because it was the volume you're targeting, probably it might not", 'have been necessary. Is that still the view? Or is that something that you might engage in to increase', 'awareness on the Model S --', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Well, I mean clearly, since we're almost -- not far from having sold out of all of next year's production of", "Model S, and it's not yet next year. There's clearly no need for advertising yet. At some point, there may", "be a need for advertising, but that's only going to be when we're not production constrained. So we're", "also going to focus our energies on ensuring that we're not production constrained. And that's why we", 'reconfigured the plan to make the Model S production, the 20,000 units production, on 1 shift instead of 2', 'shifts, so that we have the ability to potentially to double the production, fairly quickly, if need be. But we', "really don't anticipate any short- to medium-term need for advertising expenditures of any kind, really.", '']
# ['Patrick Kenehan Archambault', 'Goldman Sachs Group Inc., Research Division', '']
# Patrick Kenehan Archambault
# ['Okay. And just a couple of more housekeeping questions. I mean, Deepak, do you have -- can you give us', "the working capital number? I know that you'll give it in the queue later, but do you have that handy? And", 'the other thing I was looking for is can you give us the split in terms of the U.S. versus international sales', 'that you saw for the Roadster?', '']
# ['8', '']
# ['8', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['Let me answer the second question first. This was in fact our first quarter where we saw our international', "sales to be slightly more than U.S. sales in our history. So it's a good indication of the growth and", 'presence of Tesla outside of the U.S., in Europe and in Asia. We already really saw some good growth in', 'Japan and the Asian markets in Q1. And regarding the working capital discussion, I think our cash flow', "statement and our usage of operating cash is the answer. I'm not exactly sure what further information", "you're looking for, Pat.", '']
# ['Patrick Kenehan Archambault', 'Goldman Sachs Group Inc., Research Division', '']
# Patrick Kenehan Archambault
# ["I'm sorry, I'm just looking at it now. We can follow up online. I just saw a use in operating activity, so I", 'was just wondering what portion of that was -- in the $43 million, was a working capital use versus other', 'operating uses of cash.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['I think, as I mentioned in the call, the working capital usage would be from inventory as well as accounts', 'receivable. And those are the primary drivers for the slight increase in our working capital this quarter', 'compared to the previous one.', '']
# ['Patrick Kenehan Archambault', 'Goldman Sachs Group Inc., Research Division', '']
# Patrick Kenehan Archambault
# ['Okay. So just the Delta and those 2 items will get us the number? Okay.', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Actually, one thing I've got to mention regarding Model S is our sales team is not selling Model S. They're", "selling Roadster. So the sales growth you've seen from Model S is not due to say S ramping up the sales", "of Model S. In fact, there isn't even a Model S in the Santana Row store, I think that may not be obvious", 'based on my last comments.', '']
# ['Operator', '']
# ['Our next question is from Dan Galves of Deutsche Bank.', '']
# ['Daniel V. Galves', 'Deutsche Bank AG, Research Division', '']
# Daniel V. Galves
# ['I just wanted to ask -- interesting that the international sales were higher in the quarter than the U.S. I', 'just wanted to ask about option content uptake from consumers. It seems like it stayed pretty steady with', 'the Roadster, given steady average transaction prices. Are you seeing any differences in the amount of', 'options people buy internationally versus U.S.? And does that provide any lessons for Model S for you?', 'And then also, just a follow-up is, are you planning on offering a leasing program for the Model S? And is', 'there any update on the financing for that leasing program?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['I think our options mix is pretty comparable between regions. If there is any significant statistical', "difference, they're pretty minor. And in terms...", '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['9', '']
# ['9', '']
# ["Yes. Regarding providing a leasing option on the Model S, definitely, that is in our plan, and we've been", "working with a bank to partner with us regarding that. And we'll announce the details when they are in", "place. But we'll definitely offer leasing as a financing option for our customers.", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Yes. We're actually seeing quite strong interest from some of the major banks in working with us on a", 'leasing program for the Model S with quite compelling numbers. It looks like there may be a bit of a', 'betting war there, which is good.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["And we're also working with banks regionally in the sense, obviously, we'll have a partner in Europe", 'different from the U.S. So we will have regional concentrations there too.', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Yes. And Europe has -- I've seen us adapt to the different environments, and Europe has a very strong", "corporate leasing program. A lot of their cars are actually company cars, effectively. So we're making sure", 'that the Model S is well-positioned to be in the company car programs.', '']
# ['Daniel V. Galves', 'Deutsche Bank AG, Research Division', '']
# Daniel V. Galves
# ['Okay, excellent. Just one other one. I just wanted to ask about performance in terms of quality, quality', 'performance of the drivetrain on the Roadster. How have warranty trends been going as some of the', 'vehicles probably get a little older? Just asking about that? Has it been, to your expectations, better or', 'worse?', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["Yes, Dan. We haven't seen any significant change in the trend of our warranty work on these cars. So", "there has been no significant change in our warranty reserves. As a result, this quarter, it's been pretty", 'steady state.', '']
# ['Daniel V. Galves', 'Deutsche Bank AG, Research Division', '']
# Daniel V. Galves
# ['Great, and do you want to follow-up, Elon?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["None of our customers have actually -- no battery pack has yet reached end of light and it's been, now,", 'about 3 years. So even ones that have been driven very heavily, that are approaching 100,000 miles.', '']
# ['Operator', '']
# ['Our next question is from Adam Jonas of Morgan Stanley.', '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ['I just want to drill in a bit more on the Model S. First, the reservations. Of the 1,200 additional', "reservations you've had since the start of the year, any detail on, geographically, how those are spread?", 'And also, how much has that acceleration in the reservations been influenced by the growth in the', "footprint, in particular, the Santana Row, and knowing, of course, you don't have a vehicle in the", 'showroom. But just how much of that spur reservation activity as well?', '']
# ['10', '']
# ['10', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Well, it's difficult to say how it's spread, it's got to have some help but it's -- is how much? I think the", "biggest thing affecting Model S reservation factor is that we're sort of getting close to deliveries and", "there's a lot more detail being released about the car. And we were trying to be as open as possible to the", 'customers about the progress we make. We have journalists days, to come in and take a look at the alpha', "cars. And that's been very well received. So I think it's more press than anything else that's the bigger", 'driver. But certainly, the stores are part of it. As I said, the sales people at stores are actually instructed to', "focus on Roadster, not on Model S because we don't yet have the Model S vehicles in the stores to really", "actively sell. Model S reservations right now are, I don't have the exact numbers with me, but buyers are", 'pretty strongly towards North America. Yes, at least, sort of in the order of 3/4, North America. But part of', "that is because we'll deliver in North America first. So we deliver in North America in middle of next year,", 'Europe end of next year. And then our right-hand drive vehicle, which is key for U.K., is only in 2013. So', "I think we'll start, we'll see the mix of sales for Model S start to get roughly comparable between North", "America and Europe down the road. But that's probably happens like next year or something like that.", '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["Also, we haven't really kicked off accepting reservations for Model S.", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Right. [indiscernible] . We have to do reservation in dollars.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['Right. So as we get systematically -- while we put in the processes to collect reservations systematically', "in Asia and most of Europe, we'll see a much bigger uptick there. There is potential that we haven't really", 'exploited.', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["We don't even have a local language site. So, if you got to read it in English, you'll pay in dollars. We also", 'need to correct those issues.', '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ['And just a follow-up, and you mentioned, you have some journalist day scheduled. But specifically, when', 'can we drive it? When can we expect the journalist to begin driving either the late alpha prototype or beta', 'version realistically? And then when could you have us out there driving it ourselves?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I think, particularly, given that it's a car and safety is paramount, I think testing at the beta level is about", "the first time that we'd let non-Tesla personnel drive the car. And we're expecting to have the first betas", "done at the end of the summer. So that's about when you can expect non-Tesla people to be able to drive", 'the car. Yes.', '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ["Okay, that's clear. A question on CapEx. You're obviously running far below the run rate. You're going to", 'have to catch up to come anywhere near the $190 million to $215 million, but any way you could explain', 'to us, of the remaining 3 quarters this year, how lumpy that CapEx will be? I mean will it be smooth', '']
# ['11', '']
# ['11', '']
# ['roughly $60 million per quarter? Is it the heavily, heavily weighted towards the end of the year? Any rough', 'curve of that CapEx spend would be appreciated.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['I think it will be fairly, fairly small delivered [ph] 3 quarters. CapEx statements, as you can imagine, tend', 'to be large and lumpy. So even a 1 week or 2 delay in payment can significantly move the recognition of', "CapEx from 1 quarter to the other. So I wouldn't be very far more clear in my guidance on that issue, but", 'we have very clear visibility of what our CapEx spending will be over the next few quarters, and yes...', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['[indiscernible] CapEx expenditures, but not to the granularity of the quarter. Because like a few payments', "delayed, 1 month to next, can make a pretty big difference. But I mean, there's apart from a few minor", 'ones, all of our supplier deals are done. I mean the Model S is almost 100% sold at this point. So we --', "unless suppliers break their deals or something, then it's in the premium [ph] quantities.", '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ["But the point is, is that the lower spending level isn't so much that you're getting more bang for the buck.", "It's just that lumpiness and the timing issue and you...", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Yes.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['Exactly.', '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ["Okay, that's clear.", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I think we're getting pretty good bang for the buck to begin with.", '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ['Right, the bar is raised for you.', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["That's true. Yes. And based with the capital we have on hand and the DoE loan, we do have enough capital", 'based on our projections to reach cash flow positive and possible to without ever-raising another dollar.', "But as we said in the last quarter, there's a decent chance for lower rates secondary for the Model X", "activity, some additional potential headwind growth on the Model S production. And then, just -- it's a", 'good idea to have a larger road [ph] but smaller cash cushion.', '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ['12', '']
# ['12', '']
# ['Since you brought that up, one final question then. I mean, you mentioned the word secondary. Would', 'you preferred -- I mean, obviously, leaving room to be opportunistic and whatever method of capital raise', 'you would do, is the preference more towards equity rather than debt or convert?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I think we're probably on earning side of equity. Since we have a favored effect with the DoE loan.", '']
# ['Adam Michael Jonas', 'Morgan Stanley, Research Division', '']
# Adam Michael Jonas
# ["You'll probably not going to get better rate than that?", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["It's pretty nice.", '']
# ['Operator', '']
# ['Our next question is from Himanshu Patel with JP Morgan.', '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ['A couple of questions, just on the issue of additional fund-raising. Elon, maybe, or Deepak, can you talk a', 'little bit about, just aside from market conditions, what are the kind of key governing factors that is going', 'to help you guys decide how much to raise and when to raise? Is this really just about primarily the Model', "X and how fast you'd like to follow up with another car after the Model S? Or are there other things here", "that we're not thinking about? And I want to supplement that question, could additional fund-raising needs", 'also be satisfied with may be having another strategic investor come into the company as opposed to a', 'public market transaction?', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["I think, Himanshu, I'd like to just sort of step back and not answer this question to this level of detail. I", 'think, as you can imagine, like any other company, we will evaluate our fund-raising needs from time to', 'time, and raise funds opportunistically when it makes sense and when the market conditions are right. So', "I think, it's probably best to leave it at that regarding this question.", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Yes. Obviously, in compliance with financial regulations, we have to be circumspect in discussing future', 'financing.', '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ["Okay. The other big question I have is just since you've done your IPO, the euro is up 20%, 25%, and", "I'm just wondering what are kind of the implications of that operationally? You mentioned how the", "European deliveries for the Model S are kind of end of '12 or go '13. Does it make sense to potentially", 'accelerate some of that and maybe deemphasize U.S. deliveries initially? And I guess, in addition to', 'that, at a minimum, should we think about the currency rate changes as -- at least being just a direct', 'margin addition to the company on the non-U.S. sales? Or would you consider recalibrating your pricing', 'expectations on European volumes as a result as well?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['13', '']
# ['13', '']
# ['The reason for starting with the U.S. deliveries is, if we have to deal with any corrective actions on the', "cars, it's a lot easier to get our hands around it if it's in a more tightly contained geographic area and", "closer to our headquarters. So I think it's important for those first few months to be able to monitor very", 'closely the status of the cars and make sure customers have a wonderful experience and in a worst-', 'case scenario, where there is potentially a recourse or something like that, we can do that quickly and', "take care of it with minimal disruption. And then, it's also important to note that a car which meets U.S.", "regulations doesn't meet European regulations. So it's not like it's the car in both cases. Unfortunately,", "they are slightly different. And so, we have to decide which car do we bold first. It's not the same car to", "either market. I think it's possible we could make a little more money if we ship to Europe, maybe even", 'probable if we ship to Europe initially. But I think, the right decision in terms of long-term thinking is to', "deliver cars initially in the U.S., make sure they're super good, and then expand internationally.", '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ['And I guess the second question I had is, I think you guys have originally talked about U.S. versus non-', "U.S. volumes for the Model S eventually being kind of even. Just given what's happened...", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['I said, North America and Europe would be about even. I think Asia would be at least as big as those. I', "would say it's something like 1/3 Asia, 1/3 North America, 1/3 Europe.", '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ["Right. Okay. So I mean just given what the dollar's done, obviously, that's financially very beneficial for", "your percent margin because you're the only U.S. carmaker exporting from the U.S. really. So I guess", 'the question, Elon, is do you kind of just keep your pricing for that vehicle where you expected it and let', 'it all drop down to margin? Or is there a thought here that you could actually grab a lot more volume in', 'the non-U.S. markets to know what currency rates have done by lowering the price points that you were', 'previously thinking about?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I think it's a bit dodgy to try to guess currency, and because what's true today can be different a year", 'from now. And so I think -- we just want to perceive by way of making sure we have the best product at', 'the best price and with incredible value for money in each market. And if some customers are getting a', 'better deal because of their currencies, should develop [indiscernible] and then get to them.', '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ['Has Toyota made any decisions on the final assembly site for the RAV4?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I don't want to speak on Toyota's behalf. So I would ask you to direct that question to Toyota. But", 'certainly, the powertrain is made by Tesla in California.', '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ["Previously, you've sort of indicated that Tesla is, I guess, agnostic, is maybe the best adjective as to", 'whether or not Toyota wants to do final assembly on Fremont or not. I mean is that still pretty much your', 'view?', '']
# ['Elon R. Musk', '']
# Elon R. Musk
# ['14', '']
# ['14', '']
# ['Co-Founder, CEO, Director & Product Architect', '']
# ["Toyota is an important customer. We're a supplier to Toyota. So we want to do whatever makes Toyota", 'happy in this regard. And where the powertrain is installed is entirely up to them.', '']
# ['Himanshu A. Patel', 'JP Morgan Chase & Co, Research Division', '']
# Himanshu A. Patel
# ["Okay. Can you update us lastly on, I know it's fairly early stages, but on the Model X, you've been talking", 'a little bit more about it publicly, and I think privately. Have you put any more granularity behind your', 'thoughts on timing, any design elements that have kind of been a little bit more solidified in your mind,', 'price points, or is it still all at a fairly conceptual level?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["We're actually hard at work on the Model X in the design studio. But I don't want to let the cat out of the", "bag on what it's going to be like. I mean I think it's shaping up to be something pretty incredible. But I", "think, we'll let the public be the judge when they see it at the end of this -- we are planning to unveil it at", 'the end of the year, as I said previously. And it will use the same basic -- same powertrain as the Model S.', 'The Model X is built from the Model S platform. So it allows us to leverage that platform with a relatively', 'small amount of incremental CapEx. And it just addresses a market that is SUV and minivan. So with the', 'Model S, we try to make a sedan that is so functional, has so much cargo capacity, can seat 7 people,', 'such that it addresses those of the sedan market, but also addresses about half of the people that would', "otherwise buy an SUV. With the Model X, we're trying to address the other half of people who would buy", "SUV, as well as the people who would buy a minivan. So I'm pretty excited about it, and I think it's going", "to be well received. But we'll see at the end of this year.", '']
# ['Operator', '']
# ['Our next question is from Andrea James of Dougherty.', '']
# ['Andrea Susan James', 'Dougherty & Company LLC, Research Division', '']
# Andrea Susan James
# ["Taking back on the Model X question, do you think there'll be, I guess, some synergies from developing", 'the RAV4? Do you take any of that and move that over and capture that for the Model X development?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["There's a little bit. I wouldn't say it's lot, but there's certainly a little bit of that, that it's in there. And", 'of course, working with Toyota, and meeting their extremely stringent standards, as with Daimler, is a', "learning experience for us. So I think it's definitely helpful, with a lot of mutual learning taking place", "with us and Toyota. And so, it's definitely a helpful relationship that has intangible benefits beyond the", '[indiscernible] being the partnering style for the RAV4.', '']
# ['Andrea Susan James', 'Dougherty & Company LLC, Research Division', '']
# Andrea Susan James
# ["And as far as R&D long-term and headcount, can you talk a little bit about how you're going to manage", "headcount going into FY '12, what your expectations are, and then into FY '13?", '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["I think that is something we haven't shared much in terms of guidance, Andrea. Obviously, at a higher", 'level, our focus this year is to continue to grow our manufacturing team and then bring in the workforce to', "manufacture the car, and a lot of engineering people are already in place since we've spend the time and", "the effort to develop the Model S. So I'll just leave it at that.", '']
# ['15', '']
# ['15', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Yes. That's sort of the significant double-digit growth in play counts. But yes, it's a little bleak, but", "it's exactly what that number is going to be. Our hiring standard at Tesla are extremely high in that", 'unequivocally the highest in the car business. And so that tends to be the getting factor on our hiring', 'decisions more than anything else.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['The other area that we will see some hiring towards the end of this year and next year is marketing and', "sales as we've put in the infrastructure to sell 20,000 units of Model S globally.", '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Right, absolutely.', '']
# ['Andrea Susan James', 'Dougherty & Company LLC, Research Division', '']
# Andrea Susan James
# ['You had a great gross margin this quarter. Can you talk about the sustainability of that? And once the', 'Model S is launched, I guess maybe some of your R&D, does that move up into cost of goods sold?', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['Yes. Our gross margin on the Automotive side of the business is fairly steady. The gross margin on the', 'development services side is unpredictable because of timing differences and the recognition of revenue', 'and cost. So you would definitely see some variation in our gross margin overall, depending on the size', 'and the accounting issues around development services. Does that answer your question?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['The Model S, we are expecting higher gross margins with Model S than the Roadster because we are in', 'sourcing much more of the Model S.', '']
# ['Andrea Susan James', 'Dougherty & Company LLC, Research Division', '']
# Andrea Susan James
# ["One final one. What's your confidence level with your part sourcing and your suppliers and the delivery?", "I know it's -- just where you are right now, obviously, you're confident you're going to get there. But just", 'how do you feel about it now? And then also, with the manufacturing equipment, are there any delays,', 'anything coming from Japan? Yes, so confidence level on suppliers and on manufacturing equipment?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["Just to elaborate on the last one, we're pretty confident of the 25% gross margin number for Model", "S. That's the number that we expect to be measured by and that we're confident we'll hit. As far as", "supplier disruptions, we haven't really seen any significant supplier disruptions. So things are proceeding", 'pretty smoothly. There are a few hiccups here and there for a week or so, but it was less than our buffer', "inventories so it didn't, it really didn't to make a difference.", '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["And it hasn't affected on both the Roadster and Model S.", '']
# ['Operator', '']
# ['16', '']
# ['16', '']
# ['[Operator Instructions] Our next question is from Brian [ph] Russell of Russell Group.', '']
# ['Unknown Analyst', '']
# Unknown Analyst
# ['Could you talk a little bit about the Daimler situation? You had an additional 300 Smart battery packs', 'ordered. But I saw somewhere where they decided to go with Bosch on the motors?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ["I think you'll note it's sort of an article that didn't actually mean anything. Because we don't supply the", 'motors to Daimler. So in the case of Toyota, we do. For the RAV4, we provide the whole powertrain motor,', 'inverter, charger, transmission, and it all connects to everything. So we do it with the whole powertrain', "in the case of RAV4. In case of the Smart and the, let's say, it's A-Class, we provide the battery pack and", "charger and that's always how it's been.", '']
# ['Unknown Analyst', '']
# Unknown Analyst
# ['They said they were going to use Evonik for their battery packs on the production Smart. Is that correct or', 'have you heard anything on that?', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['That also has been their plan for or their stated plan for quite a long time. However, they also -- what has', "happened, at least historically, is that Evonik has not been able to provide a product that's as compelling", "as Tesla's, and so then Daimler has, at a very early stage of the process, driven to continue with Tesla.", "That may change in the future of course, but that's the history stated.", '']
# ['Unknown Analyst', '']
# Unknown Analyst
# ['And would I be right in assuming you kind of upped the revenue projection by about $10 million. About', 'half of is the additional 300 Smart battery charger?', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ["That's correct.", '']
# ['Unknown Analyst', '']
# Unknown Analyst
# ['And then where do you see the rest of it? Is it going to be in development services or...', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['We just have better visibility on all aspects of our business. And it could be from either or. We just feel', 'more comfortable at this point, given that we are in May here with that $10 million increase in revenue', 'guidance.', '']
# ['Operator', '']
# ["Thank you. I'm showing no further questions at this time. I'd like to turn the call over to management for", 'any closing remarks.', '']
# ['Jeffrey K. Evanson', 'Former Vice President of Investor Relations', '']
# Jeffrey K. Evanson
# ['Okay. Thank you, Tyrone. We again appreciate all of you taking your time to join us today, and we look', "forward to see many of you during our travels. We're here in Palo Alto or at our first annual shareholder", 'meeting on Wednesday, June 1 from 9 to 10 a.m. The meeting will be held at the Network Meeting Center', 'at TechMart in Santa Clara, California. Thank you, everyone, and have a great day.', '']
# ['17', '']
# ['17', '']
# ['Elon R. Musk', 'Co-Founder, CEO, Director & Product Architect', '']
# Elon R. Musk
# ['Thanks.', '']
# ['Deepak Ahuja', 'Former Chief Financial Officer', '']
# Deepak Ahuja
# ['Thank you.', '']
# ['Operator', "Ladies and gentlemen, thank you for participation in today's conference. This concludes the program. You", 'may now disconnect, and have a wonderful day.', '']
# ['18', '']
# ['18', '']
# ['19', '']

# %%
speech_speech_executives_index_list=[]

for i in speech_executives_index_dict.items():

    speech_speech_executives_index_list.append(i[1])

speech_speech_executives_index_list=np.array(speech_speech_executives_index_list)+1

# %%
speech_speech_analysts_index_list=[]

for i in speech_analysts_index_dict.items():

    speech_speech_analysts_index_list.append(i[1])

speech_speech_analysts_index_list=np.array(speech_speech_analysts_index_list)+1

# %%
speech_speech_executives_dict=defaultdict(lambda: defaultdict(list))

for i in speech_executives_index_dict.items():
    
    print(i)
    
    speech_speech_executives_dict[i[0]][i[1]].append(question_and_answer_speech[i[1]])
# Out:
# ('answer_0', 6)
# ('answer_1', 10)
# ('answer_2', 16)
# ('answer_3', 20)
# ('answer_4', 24)
# ('answer_5', 30)
# ('answer_6', 32)
# ('answer_7', 36)
# ('answer_8', 38)
# ('answer_9', 40)
# ('answer_10', 44)
# ('answer_11', 48)
# ('answer_12', 56)
# ('answer_13', 58)
# ('answer_14', 60)
# ('answer_15', 62)
# ('answer_16', 64)
# ('answer_17', 68)
# ('answer_18', 75)
# ('answer_19', 77)
# ('answer_20', 81)
# ('answer_21', 83)
# ('answer_22', 87)
# ('answer_23', 91)
# ('answer_24', 97)
# ('answer_25', 101)
# ('answer_26', 107)
# ('answer_27', 109)
# ('answer_28', 113)
# ('answer_29', 119)
# ('answer_30', 123)
# ('answer_31', 127)
# ('answer_32', 131)
# ('answer_33', 138)
# ('answer_34', 144)
# ('answer_35', 148)
# ('answer_36', 152)
# ('answer_37', 154)
# ('answer_38', 156)
# ('answer_39', 160)
# ('answer_40', 162)
# ('answer_41', 166)
# ('answer_42', 168)
# ('answer_43', 176)
# ('answer_44', 180)
# ('answer_45', 184)
# ('answer_46', 188)
# ('answer_47', 192)
# ('answer_48', 196)
# ('answer_49', 198)

# %%
speech_speech_analysts_dict=defaultdict(lambda: defaultdict(list))

for i in speech_analysts_index_dict.items():
    
    print(i)
    
    speech_speech_analysts_dict[i[0]][i[1]].append(question_and_answer_speech[i[1]])
# Out:
# ('question_0', 4)
# ('question_1', 8)
# ('question_2', 12)
# ('question_3', 18)
# ('question_4', 22)
# ('question_5', 28)
# ('question_6', 42)
# ('question_7', 46)
# ('question_8', 52)
# ('question_9', 66)
# ('question_10', 70)
# ('question_11', 79)
# ('question_12', 85)
# ('question_13', 89)
# ('question_14', 93)
# ('question_15', 99)
# ('question_16', 105)
# ('question_17', 111)
# ('question_18', 117)
# ('question_19', 121)
# ('question_20', 125)
# ('question_21', 129)
# ('question_22', 136)
# ('question_23', 142)
# ('question_24', 146)
# ('question_25', 158)
# ('question_26', 164)
# ('question_27', 174)
# ('question_28', 178)
# ('question_29', 182)
# ('question_30', 186)

# %%
speech_speech_analysts_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'question_0': defaultdict(list,
#                          {4: ["So I guess a couple questions, maybe first on just the marketing side. You've opened up Santana Row\nand I believe there was some talk about also broadening up the approach to have maybe smaller selling\npoints in public places like malls and stuff like that. Can you tell us a little bit about like how your retailing\nstrategy has evolved now that you are obviously ramping it up more aggressively? That would be my first\nquestion.\n"]}),
#              'question_1': defaultdict(list,
#                          {8: ["And I guess, just building on that, is your -- I believe the original plan was to not really do much\ntraditional marketing at all. I guess, because it was the volume you're targeting, probably it might not\nhave been necessary. Is that still the view? Or is that something that you might engage in to increase\nawareness on the Model S --\n"]}),
#              'question_2': defaultdict(list,
#                          {12: ["Okay. And just a couple of more housekeeping questions. I mean, Deepak, do you have -- can you give us\nthe working capital number? I know that you'll give it in the queue later, but do you have that handy? And\nthe other thing I was looking for is can you give us the split in terms of the U.S. versus international sales\nthat you saw for the Roadster?\n"]}),
#              'question_3': defaultdict(list,
#                          {18: ["I'm sorry, I'm just looking at it now. We can follow up online. I just saw a use in operating activity, so I\nwas just wondering what portion of that was -- in the $43 million, was a working capital use versus other\noperating uses of cash.\n"]}),
#              'question_4': defaultdict(list,
#                          {22: ['Okay. So just the Delta and those 2 items will get us the number? Okay.\n']}),
#              'question_5': defaultdict(list,
#                          {28: ['I just wanted to ask -- interesting that the international sales were higher in the quarter than the U.S. I\njust wanted to ask about option content uptake from consumers. It seems like it stayed pretty steady with\nthe Roadster, given steady average transaction prices. Are you seeing any differences in the amount of\noptions people buy internationally versus U.S.? And does that provide any lessons for Model S for you?\nAnd then also, just a follow-up is, are you planning on offering a leasing program for the Model S? And is\nthere any update on the financing for that leasing program?\n']}),
#              'question_6': defaultdict(list,
#                          {42: ['Okay, excellent. Just one other one. I just wanted to ask about performance in terms of quality, quality\nperformance of the drivetrain on the Roadster. How have warranty trends been going as some of the\nvehicles probably get a little older? Just asking about that? Has it been, to your expectations, better or\nworse?\n']}),
#              'question_7': defaultdict(list,
#                          {46: ['Great, and do you want to follow-up, Elon?\n']}),
#              'question_8': defaultdict(list,
#                          {52: ["I just want to drill in a bit more on the Model S. First, the reservations. Of the 1,200 additional\nreservations you've had since the start of the year, any detail on, geographically, how those are spread?\nAnd also, how much has that acceleration in the reservations been influenced by the growth in the\nfootprint, in particular, the Santana Row, and knowing, of course, you don't have a vehicle in the\nshowroom. But just how much of that spur reservation activity as well?\n"]}),
#              'question_9': defaultdict(list,
#                          {66: ['And just a follow-up, and you mentioned, you have some journalist day scheduled. But specifically, when\ncan we drive it? When can we expect the journalist to begin driving either the late alpha prototype or beta\nversion realistically? And then when could you have us out there driving it ourselves?\n']}),
#              'question_10': defaultdict(list,
#                          {70: ["Okay, that's clear. A question on CapEx. You're obviously running far below the run rate. You're going to\nhave to catch up to come anywhere near the $190 million to $215 million, but any way you could explain\nto us, of the remaining 3 quarters this year, how lumpy that CapEx will be? I mean will it be smooth\n"]}),
#              'question_11': defaultdict(list,
#                          {79: ["But the point is, is that the lower spending level isn't so much that you're getting more bang for the buck.\nIt's just that lumpiness and the timing issue and you...\n"]}),
#              'question_12': defaultdict(list, {85: ["Okay, that's clear.\n"]}),
#              'question_13': defaultdict(list,
#                          {89: ['Right, the bar is raised for you.\n']}),
#              'question_14': defaultdict(list, {93: ['12\n']}),
#              'question_15': defaultdict(list,
#                          {99: ["You'll probably not going to get better rate than that?\n"]}),
#              'question_16': defaultdict(list,
#                          {105: ["A couple of questions, just on the issue of additional fund-raising. Elon, maybe, or Deepak, can you talk a\nlittle bit about, just aside from market conditions, what are the kind of key governing factors that is going\nto help you guys decide how much to raise and when to raise? Is this really just about primarily the Model\nX and how fast you'd like to follow up with another car after the Model S? Or are there other things here\nthat we're not thinking about? And I want to supplement that question, could additional fund-raising needs\nalso be satisfied with may be having another strategic investor come into the company as opposed to a\npublic market transaction?\n"]}),
#              'question_17': defaultdict(list,
#                          {111: ["Okay. The other big question I have is just since you've done your IPO, the euro is up 20%, 25%, and\nI'm just wondering what are kind of the implications of that operationally? You mentioned how the\nEuropean deliveries for the Model S are kind of end of '12 or go '13. Does it make sense to potentially\naccelerate some of that and maybe deemphasize U.S. deliveries initially? And I guess, in addition to\nthat, at a minimum, should we think about the currency rate changes as -- at least being just a direct\nmargin addition to the company on the non-U.S. sales? Or would you consider recalibrating your pricing\nexpectations on European volumes as a result as well?\n"]}),
#              'question_18': defaultdict(list,
#                          {117: ["And I guess the second question I had is, I think you guys have originally talked about U.S. versus non-\nU.S. volumes for the Model S eventually being kind of even. Just given what's happened...\n"]}),
#              'question_19': defaultdict(list,
#                          {121: ["Right. Okay. So I mean just given what the dollar's done, obviously, that's financially very beneficial for\nyour percent margin because you're the only U.S. carmaker exporting from the U.S. really. So I guess\nthe question, Elon, is do you kind of just keep your pricing for that vehicle where you expected it and let\nit all drop down to margin? Or is there a thought here that you could actually grab a lot more volume in\nthe non-U.S. markets to know what currency rates have done by lowering the price points that you were\npreviously thinking about?\n"]}),
#              'question_20': defaultdict(list,
#                          {125: ['Has Toyota made any decisions on the final assembly site for the RAV4?\n']}),
#              'question_21': defaultdict(list,
#                          {129: ["Previously, you've sort of indicated that Tesla is, I guess, agnostic, is maybe the best adjective as to\nwhether or not Toyota wants to do final assembly on Fremont or not. I mean is that still pretty much your\nview?\n"]}),
#              'question_22': defaultdict(list,
#                          {136: ["Okay. Can you update us lastly on, I know it's fairly early stages, but on the Model X, you've been talking\na little bit more about it publicly, and I think privately. Have you put any more granularity behind your\nthoughts on timing, any design elements that have kind of been a little bit more solidified in your mind,\nprice points, or is it still all at a fairly conceptual level?\n"]}),
#              'question_23': defaultdict(list,
#                          {142: ["Taking back on the Model X question, do you think there'll be, I guess, some synergies from developing\nthe RAV4? Do you take any of that and move that over and capture that for the Model X development?\n"]}),
#              'question_24': defaultdict(list,
#                          {146: ["And as far as R&D long-term and headcount, can you talk a little bit about how you're going to manage\nheadcount going into FY '12, what your expectations are, and then into FY '13?\n"]}),
#              'question_25': defaultdict(list,
#                          {158: ['You had a great gross margin this quarter. Can you talk about the sustainability of that? And once the\nModel S is launched, I guess maybe some of your R&D, does that move up into cost of goods sold?\n']}),
#              'question_26': defaultdict(list,
#                          {164: ["One final one. What's your confidence level with your part sourcing and your suppliers and the delivery?\nI know it's -- just where you are right now, obviously, you're confident you're going to get there. But just\nhow do you feel about it now? And then also, with the manufacturing equipment, are there any delays,\nanything coming from Japan? Yes, so confidence level on suppliers and on manufacturing equipment?\n"]}),
#              'question_27': defaultdict(list,
#                          {174: ['Could you talk a little bit about the Daimler situation? You had an additional 300 Smart battery packs\nordered. But I saw somewhere where they decided to go with Bosch on the motors?\n']}),
#              'question_28': defaultdict(list,
#                          {178: ['They said they were going to use Evonik for their battery packs on the production Smart. Is that correct or\nhave you heard anything on that?\n']}),
#              'question_29': defaultdict(list,
#                          {182: ['And would I be right in assuming you kind of upped the revenue projection by about $10 million. About\nhalf of is the additional 300 Smart battery charger?\n']}),
#              'question_30': defaultdict(list,
#                          {186: ['And then where do you see the rest of it? Is it going to be in development services or...\n']})})

# %%
speech_speech_executives_dict
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'answer_0': defaultdict(list,
#                          {6: ["Sure, our goal with Tesla though has been to try to reinvent the sales and service process, because I\nthink it's pretty bad in the conventional industry. In fact, most people would rate purchasing a car as their\nworst retail experience, some regard it as one of those [indiscernible]. So we really want to be the polar\nopposite of that. We want it to be, buying a car is something you look forward to, that it's a delightful\nexperience. We want to have stores that you're drawn to come in even if you don't really need to buy a car\nat the time. And so, we'll try -- we're reiterating, since opening up our first store a few years ago, trying\nto refine this and Santana Row is basically the latest version of the store, if you will, store version 3 or\nsomething like that. And then, I think we're really getting it pretty dialed in. We're seeing tremendous\ntrack record at the stores, thousands of people coming in per week. And while this is slightly helpful\nfor Roadster, it's really helpful for Model S and for future vehicles that we will bring out that are more\naffordable. I'd really recommend going and visiting the Santana Row store to get a visual sense of what\nI'm talking about, because it's hard to describe exactly, but easy to understand if you go there.\n"]}),
#              'answer_1': defaultdict(list,
#                          {10: ["Well, I mean clearly, since we're almost -- not far from having sold out of all of next year's production of\nModel S, and it's not yet next year. There's clearly no need for advertising yet. At some point, there may\nbe a need for advertising, but that's only going to be when we're not production constrained. So we're\nalso going to focus our energies on ensuring that we're not production constrained. And that's why we\nreconfigured the plan to make the Model S production, the 20,000 units production, on 1 shift instead of 2\nshifts, so that we have the ability to potentially to double the production, fairly quickly, if need be. But we\nreally don't anticipate any short- to medium-term need for advertising expenditures of any kind, really.\n"]}),
#              'answer_2': defaultdict(list,
#                          {16: ["Let me answer the second question first. This was in fact our first quarter where we saw our international\nsales to be slightly more than U.S. sales in our history. So it's a good indication of the growth and\npresence of Tesla outside of the U.S., in Europe and in Asia. We already really saw some good growth in\nJapan and the Asian markets in Q1. And regarding the working capital discussion, I think our cash flow\nstatement and our usage of operating cash is the answer. I'm not exactly sure what further information\nyou're looking for, Pat.\n"]}),
#              'answer_3': defaultdict(list,
#                          {20: ['I think, as I mentioned in the call, the working capital usage would be from inventory as well as accounts\nreceivable. And those are the primary drivers for the slight increase in our working capital this quarter\ncompared to the previous one.\n']}),
#              'answer_4': defaultdict(list,
#                          {24: ["Actually, one thing I've got to mention regarding Model S is our sales team is not selling Model S. They're\nselling Roadster. So the sales growth you've seen from Model S is not due to say S ramping up the sales\nof Model S. In fact, there isn't even a Model S in the Santana Row store, I think that may not be obvious\nbased on my last comments.\n"]}),
#              'answer_5': defaultdict(list,
#                          {30: ["I think our options mix is pretty comparable between regions. If there is any significant statistical\ndifference, they're pretty minor. And in terms...\n"]}),
#              'answer_6': defaultdict(list, {32: ['9\n']}),
#              'answer_7': defaultdict(list,
#                          {36: ["Yes. We're actually seeing quite strong interest from some of the major banks in working with us on a\nleasing program for the Model S with quite compelling numbers. It looks like there may be a bit of a\nbetting war there, which is good.\n"]}),
#              'answer_8': defaultdict(list,
#                          {38: ["And we're also working with banks regionally in the sense, obviously, we'll have a partner in Europe\ndifferent from the U.S. So we will have regional concentrations there too.\n"]}),
#              'answer_9': defaultdict(list,
#                          {40: ["Yes. And Europe has -- I've seen us adapt to the different environments, and Europe has a very strong\ncorporate leasing program. A lot of their cars are actually company cars, effectively. So we're making sure\nthat the Model S is well-positioned to be in the company car programs.\n"]}),
#              'answer_10': defaultdict(list,
#                          {44: ["Yes, Dan. We haven't seen any significant change in the trend of our warranty work on these cars. So\nthere has been no significant change in our warranty reserves. As a result, this quarter, it's been pretty\nsteady state.\n"]}),
#              'answer_11': defaultdict(list,
#                          {48: ["None of our customers have actually -- no battery pack has yet reached end of light and it's been, now,\nabout 3 years. So even ones that have been driven very heavily, that are approaching 100,000 miles.\n"]}),
#              'answer_12': defaultdict(list,
#                          {56: ["Well, it's difficult to say how it's spread, it's got to have some help but it's -- is how much? I think the\nbiggest thing affecting Model S reservation factor is that we're sort of getting close to deliveries and\nthere's a lot more detail being released about the car. And we were trying to be as open as possible to the\ncustomers about the progress we make. We have journalists days, to come in and take a look at the alpha\ncars. And that's been very well received. So I think it's more press than anything else that's the bigger\ndriver. But certainly, the stores are part of it. As I said, the sales people at stores are actually instructed to\nfocus on Roadster, not on Model S because we don't yet have the Model S vehicles in the stores to really\nactively sell. Model S reservations right now are, I don't have the exact numbers with me, but buyers are\npretty strongly towards North America. Yes, at least, sort of in the order of 3/4, North America. But part of\nthat is because we'll deliver in North America first. So we deliver in North America in middle of next year,\nEurope end of next year. And then our right-hand drive vehicle, which is key for U.K., is only in 2013. So\nI think we'll start, we'll see the mix of sales for Model S start to get roughly comparable between North\nAmerica and Europe down the road. But that's probably happens like next year or something like that.\n"]}),
#              'answer_13': defaultdict(list,
#                          {58: ["Also, we haven't really kicked off accepting reservations for Model S.\n"]}),
#              'answer_14': defaultdict(list,
#                          {60: ['Right. [indiscernible] . We have to do reservation in dollars.\n']}),
#              'answer_15': defaultdict(list,
#                          {62: ["Right. So as we get systematically -- while we put in the processes to collect reservations systematically\nin Asia and most of Europe, we'll see a much bigger uptick there. There is potential that we haven't really\nexploited.\n"]}),
#              'answer_16': defaultdict(list,
#                          {64: ["We don't even have a local language site. So, if you got to read it in English, you'll pay in dollars. We also\nneed to correct those issues.\n"]}),
#              'answer_17': defaultdict(list,
#                          {68: ["I think, particularly, given that it's a car and safety is paramount, I think testing at the beta level is about\nthe first time that we'd let non-Tesla personnel drive the car. And we're expecting to have the first betas\ndone at the end of the summer. So that's about when you can expect non-Tesla people to be able to drive\nthe car. Yes.\n"]}),
#              'answer_18': defaultdict(list,
#                          {75: ["I think it will be fairly, fairly small delivered [ph] 3 quarters. CapEx statements, as you can imagine, tend\nto be large and lumpy. So even a 1 week or 2 delay in payment can significantly move the recognition of\nCapEx from 1 quarter to the other. So I wouldn't be very far more clear in my guidance on that issue, but\nwe have very clear visibility of what our CapEx spending will be over the next few quarters, and yes...\n"]}),
#              'answer_19': defaultdict(list,
#                          {77: ["[indiscernible] CapEx expenditures, but not to the granularity of the quarter. Because like a few payments\ndelayed, 1 month to next, can make a pretty big difference. But I mean, there's apart from a few minor\nones, all of our supplier deals are done. I mean the Model S is almost 100% sold at this point. So we --\nunless suppliers break their deals or something, then it's in the premium [ph] quantities.\n"]}),
#              'answer_20': defaultdict(list, {81: ['Yes.\n']}),
#              'answer_21': defaultdict(list, {83: ['Exactly.\n']}),
#              'answer_22': defaultdict(list,
#                          {87: ["I think we're getting pretty good bang for the buck to begin with.\n"]}),
#              'answer_23': defaultdict(list,
#                          {91: ["That's true. Yes. And based with the capital we have on hand and the DoE loan, we do have enough capital\nbased on our projections to reach cash flow positive and possible to without ever-raising another dollar.\nBut as we said in the last quarter, there's a decent chance for lower rates secondary for the Model X\nactivity, some additional potential headwind growth on the Model S production. And then, just -- it's a\ngood idea to have a larger road [ph] but smaller cash cushion.\n"]}),
#              'answer_24': defaultdict(list,
#                          {97: ["I think we're probably on earning side of equity. Since we have a favored effect with the DoE loan.\n"]}),
#              'answer_25': defaultdict(list, {101: ["It's pretty nice.\n"]}),
#              'answer_26': defaultdict(list,
#                          {107: ["I think, Himanshu, I'd like to just sort of step back and not answer this question to this level of detail. I\nthink, as you can imagine, like any other company, we will evaluate our fund-raising needs from time to\ntime, and raise funds opportunistically when it makes sense and when the market conditions are right. So\nI think, it's probably best to leave it at that regarding this question.\n"]}),
#              'answer_27': defaultdict(list,
#                          {109: ['Yes. Obviously, in compliance with financial regulations, we have to be circumspect in discussing future\nfinancing.\n']}),
#              'answer_28': defaultdict(list, {113: ['13\n']}),
#              'answer_29': defaultdict(list,
#                          {119: ["I said, North America and Europe would be about even. I think Asia would be at least as big as those. I\nwould say it's something like 1/3 Asia, 1/3 North America, 1/3 Europe.\n"]}),
#              'answer_30': defaultdict(list,
#                          {123: ["I think it's a bit dodgy to try to guess currency, and because what's true today can be different a year\nfrom now. And so I think -- we just want to perceive by way of making sure we have the best product at\nthe best price and with incredible value for money in each market. And if some customers are getting a\nbetter deal because of their currencies, should develop [indiscernible] and then get to them.\n"]}),
#              'answer_31': defaultdict(list,
#                          {127: ["I don't want to speak on Toyota's behalf. So I would ask you to direct that question to Toyota. But\ncertainly, the powertrain is made by Tesla in California.\n"]}),
#              'answer_32': defaultdict(list, {131: ['14\n']}),
#              'answer_33': defaultdict(list,
#                          {138: ["We're actually hard at work on the Model X in the design studio. But I don't want to let the cat out of the\nbag on what it's going to be like. I mean I think it's shaping up to be something pretty incredible. But I\nthink, we'll let the public be the judge when they see it at the end of this -- we are planning to unveil it at\nthe end of the year, as I said previously. And it will use the same basic -- same powertrain as the Model S.\nThe Model X is built from the Model S platform. So it allows us to leverage that platform with a relatively\nsmall amount of incremental CapEx. And it just addresses a market that is SUV and minivan. So with the\nModel S, we try to make a sedan that is so functional, has so much cargo capacity, can seat 7 people,\nsuch that it addresses those of the sedan market, but also addresses about half of the people that would\notherwise buy an SUV. With the Model X, we're trying to address the other half of people who would buy\nSUV, as well as the people who would buy a minivan. So I'm pretty excited about it, and I think it's going\nto be well received. But we'll see at the end of this year.\n"]}),
#              'answer_34': defaultdict(list,
#                          {144: ["There's a little bit. I wouldn't say it's lot, but there's certainly a little bit of that, that it's in there. And\nof course, working with Toyota, and meeting their extremely stringent standards, as with Daimler, is a\nlearning experience for us. So I think it's definitely helpful, with a lot of mutual learning taking place\nwith us and Toyota. And so, it's definitely a helpful relationship that has intangible benefits beyond the\n[indiscernible] being the partnering style for the RAV4.\n"]}),
#              'answer_35': defaultdict(list,
#                          {148: ["I think that is something we haven't shared much in terms of guidance, Andrea. Obviously, at a higher\nlevel, our focus this year is to continue to grow our manufacturing team and then bring in the workforce to\nmanufacture the car, and a lot of engineering people are already in place since we've spend the time and\nthe effort to develop the Model S. So I'll just leave it at that.\n"]}),
#              'answer_36': defaultdict(list,
#                          {152: ["Yes. That's sort of the significant double-digit growth in play counts. But yes, it's a little bleak, but\nit's exactly what that number is going to be. Our hiring standard at Tesla are extremely high in that\nunequivocally the highest in the car business. And so that tends to be the getting factor on our hiring\ndecisions more than anything else.\n"]}),
#              'answer_37': defaultdict(list,
#                          {154: ["The other area that we will see some hiring towards the end of this year and next year is marketing and\nsales as we've put in the infrastructure to sell 20,000 units of Model S globally.\n"]}),
#              'answer_38': defaultdict(list, {156: ['Right, absolutely.\n']}),
#              'answer_39': defaultdict(list,
#                          {160: ['Yes. Our gross margin on the Automotive side of the business is fairly steady. The gross margin on the\ndevelopment services side is unpredictable because of timing differences and the recognition of revenue\nand cost. So you would definitely see some variation in our gross margin overall, depending on the size\nand the accounting issues around development services. Does that answer your question?\n']}),
#              'answer_40': defaultdict(list,
#                          {162: ['The Model S, we are expecting higher gross margins with Model S than the Roadster because we are in\nsourcing much more of the Model S.\n']}),
#              'answer_41': defaultdict(list,
#                          {166: ["Just to elaborate on the last one, we're pretty confident of the 25% gross margin number for Model\nS. That's the number that we expect to be measured by and that we're confident we'll hit. As far as\nsupplier disruptions, we haven't really seen any significant supplier disruptions. So things are proceeding\npretty smoothly. There are a few hiccups here and there for a week or so, but it was less than our buffer\ninventories so it didn't, it really didn't to make a difference.\n"]}),
#              'answer_42': defaultdict(list,
#                          {168: ["And it hasn't affected on both the Roadster and Model S.\n"]}),
#              'answer_43': defaultdict(list,
#                          {176: ["I think you'll note it's sort of an article that didn't actually mean anything. Because we don't supply the\nmotors to Daimler. So in the case of Toyota, we do. For the RAV4, we provide the whole powertrain motor,\ninverter, charger, transmission, and it all connects to everything. So we do it with the whole powertrain\nin the case of RAV4. In case of the Smart and the, let's say, it's A-Class, we provide the battery pack and\ncharger and that's always how it's been.\n"]}),
#              'answer_44': defaultdict(list,
#                          {180: ["That also has been their plan for or their stated plan for quite a long time. However, they also -- what has\nhappened, at least historically, is that Evonik has not been able to provide a product that's as compelling\nas Tesla's, and so then Daimler has, at a very early stage of the process, driven to continue with Tesla.\nThat may change in the future of course, but that's the history stated.\n"]}),
#              'answer_45': defaultdict(list, {184: ["That's correct.\n"]}),
#              'answer_46': defaultdict(list,
#                          {188: ['We just have better visibility on all aspects of our business. And it could be from either or. We just feel\nmore comfortable at this point, given that we are in May here with that $10 million increase in revenue\nguidance.\n']}),
#              'answer_47': defaultdict(list,
#                          {192: ["Okay. Thank you, Tyrone. We again appreciate all of you taking your time to join us today, and we look\nforward to see many of you during our travels. We're here in Palo Alto or at our first annual shareholder\nmeeting on Wednesday, June 1 from 9 to 10 a.m. The meeting will be held at the Network Meeting Center\nat TechMart in Santa Clara, California. Thank you, everyone, and have a great day.\n"]}),
#              'answer_48': defaultdict(list, {196: ['Thanks.\n']}),
#              'answer_49': defaultdict(list, {198: ['Thank you.\n']})})
